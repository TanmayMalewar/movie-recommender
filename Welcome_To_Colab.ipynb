# %%
# !pip install numpy pandas scikit-learn

# %%
import pandas as pd

movies = pd.DataFrame({
    "title": [
        "Batman Begins",
        "The Dark Knight",
        "Inception",
        "Interstellar",
        "The Matrix",
        "Avengers Endgame",
        "Iron Man",
        "Joker"
    ],

    "tags": [
        "batman gotham crime bruce wayne ninja training",
        "joker batman gotham crime chaos thriller",
        "dreams subconscious mind bending heist",
        "space time relativity nasa black hole",
        "simulation reality humans machines matrix",
        "avengers thanos heroes battle endgame",
        "tony stark billionaire engineer iron suit",
        "joker mental illness gotham crime origin"
    ]
})

movies
# Out:
#               title                                            tags
# 0     Batman Begins  batman gotham crime bruce wayne ninja training
# 1   The Dark Knight        joker batman gotham crime chaos thriller
# 2         Inception          dreams subconscious mind bending heist
# 3      Interstellar           space time relativity nasa black hole
# 4        The Matrix       simulation reality humans machines matrix
# 5  Avengers Endgame           avengers thanos heroes battle endgame
# 6          Iron Man       tony stark billionaire engineer iron suit
# 7             Joker        joker mental illness gotham crime origin

# %%
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(max_features=2000, stop_words='english')
vectors = cv.fit_transform(movies['tags']).toarray()

# %%
from sklearn.metrics.pairwise import cosine_similarity

similarity = cosine_similarity(vectors)

# %%
def recommend(movie):
    index = movies[movies['title'] == movie].index[0]

    distances = list(enumerate(similarity[index]))
    distances = sorted(distances, key=lambda x: x[1], reverse=True)

    recommended = []

    for i in distances[1:6]:
        recommended.append(movies.iloc[i[0]].title)

    return recommended

# %%
recommend("Batman Begins")
# Out:
# ['The Dark Knight', 'Joker', 'Inception', 'Interstellar', 'The Matrix']

# %%
movie_name = input("Enter a movie name: ")

print("\n🎬 Recommended Movies:\n")

for movie in recommend(movie_name):
    print("👉", movie)
# Out:
# Enter a movie name: The Matrix
#
# 🎬 Recommended Movies:
#
# 👉 Batman Begins
# 👉 The Dark Knight
# 👉 Inception
# 👉 Interstellar
# 👉 Avengers Endgame

# %%
import pickle

pickle.dump(similarity, open("similarity.pkl", "wb"))
